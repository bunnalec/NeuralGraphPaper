# %%
from torchtext.datasets import WikiText2
from torchtext.data.utils import get_tokenizer
from torchtext.vocab import build_vocab_from_iterator
import torch
from torch import nn
from torch.utils.data import dataset
import importlib
import sys
sys.path.append("../")
from NeuralGraph import NeuralGraph
from tqdm.autonotebook import tqdm
import matplotlib.pyplot as plt
import seaborn as sb
import numpy as np
# Out:
# c:\Users\bunna\AppData\Local\Programs\Python\Python39\lib\site-packages\requests\__init__.py:102: RequestsDependencyWarning: urllib3 (1.26.16) or chardet (5.1.0)/charset_normalizer (2.0.4) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({})/charset_normalizer ({}) doesn't match a supported "

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
with open("tokipona.txt") as f:
    raw_data = f.read()

punctuation = "!,.:?\""
for c in punctuation:
    raw_data = raw_data.replace(c, "")

raw_data = raw_data.replace("\n", " ")

tokens = [word for word in raw_data.split(" ") if word != ""]

# Gonna commit a slight sin and get vocab before splitting to train/test cause I don't want to bother with <unk> token

vocab, densities = np.unique(tokens, return_counts=True)
densities = densities / np.sum(densities)
vocab = vocab[np.argsort(densities)[::-1]]# [:100]
densities = np.sort(densities)[::-1]# [:100]
vocab_size = len(vocab)

print(f"Percent of language: {100*np.sum(densities):.1f}%")

stoi = {word:i for i, word in enumerate(vocab)}
itos = {i:word for i, word in enumerate(vocab)}
# Out:
# Percent of language: 100.0%

# %%
print(len(tokens))
# Out:
# 42856

# %%
split = .7

train = tokens[:int(len(tokens)*split)]
valid = tokens[int(len(tokens)*split):int(len(tokens)*(split+(1-split)/2))]
test = tokens[int(len(tokens)*(split+(1-split)/2)):]

print(len(train), len(valid), len(test))

train_data = torch.Tensor([stoi[token] for token in train if token in stoi.keys()]).to(device).long()
valid_data = torch.Tensor([stoi[token] for token in valid if token in stoi.keys()]).to(device).long()
test_data = torch.Tensor([stoi[token] for token in test if token in stoi.keys()]).to(device).long()
# Out:
# 29999 6428 6429

# %%
# ~Zipfs law
plt.yscale("log")
plt.plot(densities)

# %%
def get_batch(source, batch_size, bptt):
    starts = torch.randint(len(source) - bptt - 1, size=(batch_size,)).to(device)
    data = torch.stack([source[start:start+bptt+1] for start in starts], axis=0)
    x_batch = data[:, :-1]
    y_batch = data[:, 1:]
    return x_batch, y_batch

# %%
x_batch, y_batch = get_batch(train_data, 32, 16)

print(x_batch.shape, y_batch.shape)
# Out:
# torch.Size([32, 16]) torch.Size([32, 16])

# %%
# Shuffles up which tokens map to which indices cuz I'm evil and want to torture the ngraph >:)
def shuffle_lang(x_batch, y_batch):
    batch_size = x_batch.shape[0]
    
    reordering = torch.stack([torch.randperm(vocab_size) for _ in range(batch_size)]).to(device)

    x_batch = torch.stack([reordering[i][x_batch[i]] for i in range(batch_size)])
    y_batch = torch.stack([reordering[i][y_batch[i]] for i in range(batch_size)])
    return x_batch, y_batch, reordering

# %%
ch_n = 8
ch_e = 8
ch_n_const = 2 # Flag for inp and out node
ch_inp = 1
ch_out = 1

emb_size = 16
# Totally Random embeddings
# enc = torch.randn(vocab_size, emb_size).to(device)
# dec = torch.linalg.pinv(enc)

# %%
n_inp = emb_size
n_hid = 16
n_out = emb_size

n_nodes = n_inp + n_hid + n_out

connections = [[i, j] for i in range(n_inp) for j in range(n_inp, n_inp + n_hid)] + \
    [[i, j] for i in range(n_inp, n_inp + n_hid) for j in range(n_inp, n_inp + n_hid)] + \
    [[i, j] for i in range(n_inp, n_inp + n_hid) for j in range(n_inp + n_hid, n_inp + n_hid + n_out)]

connections = torch.Tensor(connections)

print(connections.shape)

graph = NeuralGraph(n_nodes, n_inp, n_out, connections,
    ch_n=ch_n, ch_e=ch_e, ch_inp=ch_inp, ch_out=ch_out, ch_n_const=2, value_init="trainable", init_value_std=.01, set_nodes=False, use_label=True,
    aggregation="mean", clamp_mode="soft", max_value=20, device=device)# .to(device)# inp_enc=inp_enc, out_dec=out_dec

enc = nn.Embedding(vocab_size, emb_size).to(device)# ES.ES_classes.ES_Linear(vocab_size, emb_size).to(device)
dec = nn.Linear(emb_size, vocab_size).to(device)# ES.ES_classes.ES_Linear(emb_size, vocab_size).to(device)

optimizer = torch.optim.Adam([*graph.parameters(), *enc.parameters(), *dec.parameters()], lr=1e-3)
criterion = nn.CrossEntropyLoss(reduction='none')
# sigma = .05

log = []
# Out:
# torch.Size([768, 2])

# %%
# graph.load_state_dict(torch.load("tokipona.pt"))

# %%
const_n=torch.zeros(n_nodes, 2).to(device)
const_n[:n_inp, 0] = 1
const_n[-n_out:, 1] = 1
graph.set_const_vals(const_n)

# %%
graph.to(device)

print(graph.device)
print(graph.const_n.device, graph.init_nodes.device)
# Out:
# cuda
# cuda:0 cuda:0

# %%
steps = 100_000
T = .1
DT = T/4
batch_size = 16
bptt = 32

# with torch.no_grad():

bar = tqdm(range(1, steps+1))
for step in bar:
        x_batch, y_batch = get_batch(train_data, batch_size, bptt)
        shuffled_x, shuffled_y, orderings = shuffle_lang(x_batch, y_batch)

        optimizer.zero_grad()
        # graph.generate_epsilons(batch_size, sigma=sigma)
        # enc.generate_epsilons(batch_size, sigma)
        # dec.generate_epsilons(batch_size, sigma)

        x_emb = enc(shuffled_x)# enc(nn.functional.one_hot(shuffled_x, vocab_size).float())#  @ enc
        y_emb = enc(shuffled_y)# enc(nn.functional.one_hot(shuffled_y, vocab_size).float())#  @ enc

        graph.init_vals(nodes=True, edges=True, batch_size=batch_size)

        preds = []
        for t in range(bptt):
            pred = dec(graph.forward(x_emb[:, t], T, DT, edges=True))#  @ dec
            # graph.backward(x_emb[:, t], y_emb[:, t], T, DT, edges=False, edges_at_end=True)

            preds.append(pred)

        preds = torch.stack(preds, axis=1)
        # For some reason batch dims can be dim 0 and dims 2, 3, ...  NOT DIM 1
        losses = criterion(torch.swapaxes(preds, -1, -2), shuffled_y).mean(-1)
        loss = losses.mean().item()

        accs = (preds.argmax(-1) == shuffled_y).float().mean(-1)
        acc = accs.mean().item()

        # overflows = torch.where(graph.nodes.abs() > 5, graph.nodes.abs(), 0).mean(-1).mean(-1) + torch.where(graph.nodes.abs() > 5, graph.nodes.abs(), 0).mean(-1).mean(-1)
        # overflow = overflows.mean().item()
        overflow = graph.overflow()

        loss = overflow + losses.mean()
        loss.backward()

        # graph.estimate_grads(losses - accs + overflows, sigma=sigma, normalize=True)
        # enc.estimate_grads(losses - accs + overflows, sigma=sigma, normalize=True)
        # dec.estimate_grads(losses - accs + overflows, sigma=sigma, normalize=True)
        
        optimizer.step()

        entry = {'loss':losses.mean().item(), 'acc':acc, 'overflow':overflow.item()}
        log.append(entry)
        bar.set_postfix(entry)
# Out:
#   2%|▏         | 2182/100000 [24:25<18:15:07,  1.49it/s, loss=5.24, acc=0.00586, overflow=0]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[38], line 26
#      24 preds = []
#      25 for t in range(bptt):
# ---> 26     pred = dec(graph.forward(x_emb[:, t], T, DT, edges=True))#  @ dec
#      27     # graph.backward(x_emb[:, t], y_emb[:, t], T, DT, edges=False, edges_at_end=True)
#      29     preds.append(pred)
#
# File c:\Users\bunna\Documents\GitHub\NeuralGraphPaper\NLP\..\NeuralGraph.py:549, in NeuralGraph.forward(self, x, time, dt, apply_once, nodes, edges)
#     543         checkpoint(
#     544             self.timestep,
#     545             use_reentrant=False,
#     546             step_nodes=nodes, step_edges=edges, dt=dt, t=t
#     547         )
#     548     else:
# --> 549         self.timestep(step_nodes=nodes, step_edges=edges, dt=dt, t=t)
#     550 return self.read_outputs()
#
# File c:\Users\bunna\Documents\GitHub\NeuralGraphPaper\NLP\..\NeuralGraph.py:245, in NeuralGraph.timestep(self, dt, step_nodes, step_edges, t)
#     242 edges = self.edges.clone() if (self.pool is None) else self.edges[self.pool]
#     244 # Get messages
# --> 245 m_x = torch.cat([nodes[:, self.conn_a], nodes[:, self.conn_b], edges], dim=2)
#     246 # a = torch.stack([self.conn_a, self.conn_b, self.conn_b], dim=-1)
#     247 # m_x = nodes[:, a].flatten(2)
#     248 # m_x[:, :, self.ch_n*2:] = edges
#     249 m = self.messages[t % self.n_models](m_x)
#
# KeyboardInterrupt:

# %%
plt.plot([e["loss"] for e in log])
plt.show()
plt.plot([e["acc"] for e in log])
plt.show()

# %%
test_batch_size = 1024

with torch.no_grad():
        x_batch, y_batch = get_batch(train_data, test_batch_size, bptt)
        shuffled_x, shuffled_y, orderings = shuffle_lang(x_batch, y_batch)

        graph.generate_epsilons(test_batch_size, sigma=sigma)
        graph.init_vals(nodes=True, edges=True, batch_size=test_batch_size)

        preds = []
        for t in range(bptt):
            # Unsqueeze to represent only one input node
            pred = graph.forward(nn.functional.one_hot(shuffled_x[:, t], vocab_size), T, DT, edges=False)
            graph.backward(nn.functional.one_hot(shuffled_x[:, t], vocab_size), nn.functional.one_hot(shuffled_y[:, t], vocab_size), T, DT, edges=False, edges_at_end=True)

            preds.append(pred)

        preds = torch.stack(preds, axis=1)

        accs = (preds.argmax(-1) == shuffled_y).float().mean(0).cpu().numpy()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\bunna\Documents\GitHub\NeuralGraphPaper\NLP\tokipona.ipynb Cell 16 line 1
#      <a href='vscode-notebook-cell:/c%3A/Users/bunna/Documents/GitHub/NeuralGraphPaper/NLP/tokipona.ipynb#X21sZmlsZQ%3D%3D?line=9'>10</a> preds = []
#      <a href='vscode-notebook-cell:/c%3A/Users/bunna/Documents/GitHub/NeuralGraphPaper/NLP/tokipona.ipynb#X21sZmlsZQ%3D%3D?line=10'>11</a> for t in range(bptt):
#      <a href='vscode-notebook-cell:/c%3A/Users/bunna/Documents/GitHub/NeuralGraphPaper/NLP/tokipona.ipynb#X21sZmlsZQ%3D%3D?line=11'>12</a>     # Unsqueeze to represent only one input node
# ---> <a href='vscode-notebook-cell:/c%3A/Users/bunna/Documents/GitHub/NeuralGraphPaper/NLP/tokipona.ipynb#X21sZmlsZQ%3D%3D?line=12'>13</a>     pred = graph.forward(nn.functional.one_hot(shuffled_x[:, t], vocab_size), T, DT, edges=False)
#      <a href='vscode-notebook-cell:/c%3A/Users/bunna/Documents/GitHub/NeuralGraphPaper/NLP/tokipona.ipynb#X21sZmlsZQ%3D%3D?line=13'>14</a>     graph.backward(nn.functional.one_hot(shuffled_x[:, t], vocab_size), nn.functional.one_hot(shuffled_y[:, t], vocab_size), T, DT, edges=False, edges_at_end=True)
#      <a href='vscode-notebook-cell:/c%3A/Users/bunna/Documents/GitHub/NeuralGraphPaper/NLP/tokipona.ipynb#X21sZmlsZQ%3D%3D?line=15'>16</a>     preds.append(pred)
#
# File c:\Users\bunna\Documents\GitHub\NeuralGraphPaper\NLP\..\ES\ES_NeuralGraph.py:372, in NeuralGraph.forward(self, x, time, dt, apply_once, nodes, edges, **kwargs)
#     370     if not apply_once:
#     371         self.apply_vals(x)
# --> 372     self.timestep(step_nodes=nodes, step_edges=edges, dt=dt, t=t)
#     373 return self.read_outputs()
#
# File c:\Users\bunna\Documents\GitHub\NeuralGraphPaper\NLP\..\ES\ES_NeuralGraph.py:198, in NeuralGraph.timestep(self, dt, step_nodes, step_edges, t)
#     195     m_a, m_b = self.calc_attention(t)
#     197 # Aggregate messages
# --> 198 agg_m_a = torch.zeros(batch_size, self.n_nodes, self.ch_n-self.ch_n_const).to(self.device)
#     199 agg_m_b = torch.zeros(batch_size, self.n_nodes, self.ch_n-self.ch_n_const).to(self.device)
#     200 agg_m_a.index_add_(1, self.sources, m_a)
#
# KeyboardInterrupt:

# %%
torch.save(graph.state_dict(), "tokipona.pt")

# %%
plt.plot(accs)
plt.title("Accuracy during runtime")
plt.xlabel("Tokens seen")
plt.ylabel("Accuracy")
plt.show()

# %%
import seaborn as sb

i = 1

plt.figure(figsize=(20, 5))

sb.heatmap(preds[i, :32].cpu().T)

plt.scatter(np.arange(32)+.5, preds[i, :32].argmax(-1).cpu()+.5, s=75, label="Graph Guess")

plt.scatter(np.arange(32)+.5, shuffled_y[i, :32].cpu()+.5, s=30, c="green", label="Correct")

plt.legend()

plt.show()

plt.figure(figsize=(20, 5))

sb.heatmap(preds[i, 32:].cpu().T)

plt.scatter(np.arange(32)+.5, preds[i, 32:].argmax(-1).cpu()+.5, s=75, label="Graph Guess")

plt.scatter(np.arange(32)+.5, shuffled_y[i, 32:].cpu()+.5, s=30, c="green", label="Correct")

plt.legend()

plt.show()

# %%
# plt.imshow(graph.init_edges.cpu().detach())
plt.imshow(graph.init_nodes.cpu().detach())

# %%
print(graph.init_nodes.shape)
print(graph.const_n.shape)
# Out:
# torch.Size([16, 14])
# torch.Size([16, 2])

# %%
num_batches = train_data.shape[1] // bptt
print(num_batches)
# Out:
# 15

# %%
print(train_data.shape)
# Out:
# torch.Size([512, 4003])
